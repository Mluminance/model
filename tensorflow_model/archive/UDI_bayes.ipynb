# %%
pip install -q -U keras_tuner
# Out:
#      |████████████████████████████████| 98 kB 4.8 MB/s

# %%
# Import libraries
import sys, glob, os, time
import numpy as np
import scipy as sp
import pandas as pd
from csv import reader, writer
import joblib
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Activation, Input, Dense, Dropout, Conv2D, Conv2DTranspose, BatchNormalization, UpSampling2D, Reshape, LeakyReLU
from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils.generic_utils import get_custom_objects
import keras_tuner as kt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from IPython import display

get_custom_objects().update({'leaky-relu': Activation(LeakyReLU(alpha=0.2))})

# %%
# Activate GPU
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# current working directory
cwd = '/content/drive/MyDrive/Colab Notebooks/Daylight Autonomy/'

# %% [markdown]
# # Data setup

# %%
features_file = os.path.join(cwd, 'data', 'features.csv')
targets_file = os.path.join(cwd, 'data', 'targets.csv')

# %%
raw_features = pd.read_csv(features_file, index_col=0)
raw_targets = pd.read_csv(targets_file)

# %%
minmax = np.array([[-10,10], [-10,10], [-10,10], [-10,10],
                   [-10,10], [-10,10], [-10,10], [-10,10],
                   [2,5], [0.2,0.95], [0.2,0.95], [0,360]])

# %%
f_avg = minmax.mean(axis=1)
f_std = minmax.std(axis=1)
t_std = 100

features = (raw_features - f_avg)/f_std
targets = raw_targets/t_std

# %%
features = np.array(features)
targets = np.array(targets).reshape(len(targets),40,40)

# %%
# Split data to train, validate, test set (60% training, 20% validation, 20% test split)
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# %%
n_feat = features.shape[1]
n_tar = targets.shape[1]

# %% [markdown]
# # Model and training

# %%
# Clear keras workspace for new model
keras.backend.clear_session()

# Deconvolutional Neural Network Model (DCNN) for generating daylight autonomy
model = Sequential()

### DNN model to analysis the input parameters
model.add(Dense(32 * 6 * 6, input_dim=n_feat))
model.add(BatchNormalization())
model.add(LeakyReLU())

model.add(Dense(256 * 6 * 6))
model.add(BatchNormalization())
model.add(LeakyReLU())

### Deconvolution to generate image
model.add(Reshape((6, 6, 256)))

model.add(Conv2DTranspose(filters=128, kernel_size=5, strides=(2,2), activation='relu'))
model.add(BatchNormalization())

model.add(Conv2DTranspose(filters=64, kernel_size=5, strides=(2,2), activation='leaky-relu'))
model.add(BatchNormalization())

model.add(Conv2DTranspose(filters=64, kernel_size=5, strides=(1,1), activation='leaky-relu'))
model.add(BatchNormalization())

model.add(Conv2DTranspose(filters=64, kernel_size=5, strides=(1,1), activation='leaky-relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=1, kernel_size=2, strides=(1,1), activation='sigmoid'))

# optimizer
model.compile(optimizer=optimizers.Adam(learning_rate=0.001, beta_1=0.5, beta_2=0.999), loss="mse")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1152)              14976
#
#  batch_normalization (BatchN  (None, 1152)             4608
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 1152)              0
#
#  dense_1 (Dense)             (None, 9216)              10626048
#
#  batch_normalization_1 (Batc  (None, 9216)             36864
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 9216)              0
#
#  reshape (Reshape)           (None, 6, 6, 256)         0
#
#  conv2d_transpose (Conv2DTra  (None, 15, 15, 128)      819328
#  nspose)
#
#  batch_normalization_2 (Batc  (None, 15, 15, 128)      512
#  hNormalization)
#
#  conv2d_transpose_1 (Conv2DT  (None, 33, 33, 64)       204864
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 33, 33, 64)       256
#  hNormalization)
#
#  conv2d_transpose_2 (Conv2DT  (None, 37, 37, 64)       102464
#  ranspose)
#
#  batch_normalization_4 (Batc  (None, 37, 37, 64)       256
#  hNormalization)
#
#  conv2d_transpose_3 (Conv2DT  (None, 41, 41, 64)       102464
#  ranspose)
#
#  batch_normalization_5 (Batc  (None, 41, 41, 64)       256
#  hNormalization)
#
#  conv2d (Conv2D)             (None, 40, 40, 1)         257
#
# =================================================================
# Total params: 11,913,153
# Trainable params: 11,891,777
# Non-trainable params: 21,376
# _________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    epochs = 3000,
    batch_size = 8,
    validation_data = (X_val, y_val),
    callbacks = [
                 EarlyStopping(monitor='val_loss', patience=50, mode='min'),
                 ModelCheckpoint(filepath = 'CNN2D.ckpt', save_weights_only=True, monitor='val_loss', save_best_only=True)
    ]
)
# Out:
# Epoch 1/3000
# 120/120 [==============================] - 3s 14ms/step - loss: 0.0509 - val_loss: 0.0798
# Epoch 2/3000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0354 - val_loss: 0.0567
# Epoch 3/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0308 - val_loss: 0.0313
# Epoch 4/3000
# 120/120 [==============================] - 1s 11ms/step - loss: 0.0281 - val_loss: 0.0231
# Epoch 5/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0266 - val_loss: 0.0197
# Epoch 6/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0259 - val_loss: 0.0222
# Epoch 7/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0246 - val_loss: 0.0235
# Epoch 8/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0239 - val_loss: 0.0216
# Epoch 9/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0235 - val_loss: 0.0205
# Epoch 10/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0236 - val_loss: 0.0214
# Epoch 11/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0228 - val_loss: 0.0216
# Epoch 12/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0223 - val_loss: 0.0217
# Epoch 13/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0221 - val_loss: 0.0178
# Epoch 14/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0224 - val_loss: 0.0297
# Epoch 15/3000
# 120/120 [==============================] - 1s 11ms/step - loss: 0.0213 - val_loss: 0.0180
# Epoch 16/3000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0203 - val_loss: 0.0177
# Epoch 17/3000
# 120/120 [==============================] - 2s 15ms/step - loss: 0.0211 - val_loss: 0.0167
# Epoch 18/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0201 - val_loss: 0.0179
# Epoch 19/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0216 - val_loss: 0.0202
# Epoch 20/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0201 - val_loss: 0.0168
# Epoch 21/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0197 - val_loss: 0.0168
# Epoch 22/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0191 - val_loss: 0.0183
# Epoch 23/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 24/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0200 - val_loss: 0.0169
# Epoch 25/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0196 - val_loss: 0.0166
# Epoch 26/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0191 - val_loss: 0.0160
# Epoch 27/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0197 - val_loss: 0.0169
# Epoch 28/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0192 - val_loss: 0.0177
# Epoch 29/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0186 - val_loss: 0.0158
# Epoch 30/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0182 - val_loss: 0.0167
# Epoch 31/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0167
# Epoch 32/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0181 - val_loss: 0.0169
# Epoch 33/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0178 - val_loss: 0.0170
# Epoch 34/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0182 - val_loss: 0.0173
# Epoch 35/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0173 - val_loss: 0.0151
# Epoch 36/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0174 - val_loss: 0.0185
# Epoch 37/3000
# 120/120 [==============================] - 2s 13ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 38/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0177 - val_loss: 0.0150
# Epoch 39/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0175 - val_loss: 0.0156
# Epoch 40/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0180 - val_loss: 0.0162
# Epoch 41/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 42/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0177 - val_loss: 0.0171
# Epoch 43/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0181 - val_loss: 0.0157
# Epoch 44/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0175 - val_loss: 0.0149
# Epoch 45/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0164 - val_loss: 0.0150
# Epoch 46/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0171 - val_loss: 0.0169
# Epoch 47/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0172 - val_loss: 0.0159
# Epoch 48/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0172 - val_loss: 0.0162
# Epoch 49/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0169 - val_loss: 0.0156
# Epoch 50/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0163 - val_loss: 0.0145
# Epoch 51/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 52/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0160 - val_loss: 0.0156
# Epoch 53/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0158 - val_loss: 0.0150
# Epoch 54/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0162 - val_loss: 0.0156
# Epoch 55/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0161 - val_loss: 0.0155
# Epoch 56/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0162 - val_loss: 0.0146
# Epoch 57/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0160 - val_loss: 0.0151
# Epoch 58/3000
# 120/120 [==============================] - 2s 14ms/step - loss: 0.0155 - val_loss: 0.0145
# Epoch 59/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0161 - val_loss: 0.0149
# Epoch 60/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0164 - val_loss: 0.0155
# Epoch 61/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0153 - val_loss: 0.0151
# Epoch 62/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0153 - val_loss: 0.0150
# Epoch 63/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0162 - val_loss: 0.0145
# Epoch 64/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0158 - val_loss: 0.0156
# Epoch 65/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0147 - val_loss: 0.0153
# Epoch 66/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0154 - val_loss: 0.0158
# Epoch 67/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 68/3000
# 120/120 [==============================] - 2s 13ms/step - loss: 0.0152 - val_loss: 0.0144
# Epoch 69/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0153 - val_loss: 0.0164
# Epoch 70/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0148 - val_loss: 0.0145
# Epoch 71/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0150 - val_loss: 0.0143
# Epoch 72/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0151 - val_loss: 0.0159
# Epoch 73/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0148 - val_loss: 0.0157
# Epoch 74/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 75/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0147 - val_loss: 0.0151
# Epoch 76/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0147 - val_loss: 0.0143
# Epoch 77/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0143 - val_loss: 0.0154
# Epoch 78/3000
# 120/120 [==============================] - 1s 11ms/step - loss: 0.0143 - val_loss: 0.0141
# Epoch 79/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0147 - val_loss: 0.0147
# Epoch 80/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0141 - val_loss: 0.0149
# Epoch 81/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0147 - val_loss: 0.0146
# Epoch 82/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0145 - val_loss: 0.0164
# Epoch 83/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0146 - val_loss: 0.0150
# Epoch 84/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0147 - val_loss: 0.0144
# Epoch 85/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0141 - val_loss: 0.0144
# Epoch 86/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0139 - val_loss: 0.0155
# Epoch 87/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0138 - val_loss: 0.0148
# Epoch 88/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0128 - val_loss: 0.0144
# Epoch 89/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0141 - val_loss: 0.0150
# Epoch 90/3000
# 120/120 [==============================] - 1s 12ms/step - loss: 0.0140 - val_loss: 0.0140
# Epoch 91/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0137 - val_loss: 0.0145
# Epoch 92/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 93/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0136 - val_loss: 0.0141
# Epoch 94/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0133 - val_loss: 0.0153
# Epoch 95/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0135 - val_loss: 0.0157
# Epoch 96/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0137 - val_loss: 0.0157
# Epoch 97/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0136 - val_loss: 0.0157
# Epoch 98/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0131 - val_loss: 0.0149
# Epoch 99/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0131 - val_loss: 0.0151
# Epoch 100/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0134 - val_loss: 0.0148
# Epoch 101/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0133 - val_loss: 0.0149
# Epoch 102/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0135 - val_loss: 0.0146
# Epoch 103/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0134 - val_loss: 0.0147
# Epoch 104/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0126 - val_loss: 0.0151
# Epoch 105/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0132 - val_loss: 0.0159
# Epoch 106/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0129 - val_loss: 0.0154
# Epoch 107/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0129 - val_loss: 0.0157
# Epoch 108/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0131 - val_loss: 0.0155
# Epoch 109/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0134 - val_loss: 0.0149
# Epoch 110/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0128 - val_loss: 0.0151
# Epoch 111/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0129 - val_loss: 0.0146
# Epoch 112/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0123 - val_loss: 0.0159
# Epoch 113/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0130 - val_loss: 0.0150
# Epoch 114/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0126 - val_loss: 0.0150
# Epoch 115/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0131 - val_loss: 0.0148
# Epoch 116/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0122 - val_loss: 0.0150
# Epoch 117/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0125 - val_loss: 0.0154
# Epoch 118/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0129 - val_loss: 0.0156
# Epoch 119/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0120 - val_loss: 0.0151
# Epoch 120/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0120 - val_loss: 0.0149
# Epoch 121/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0131 - val_loss: 0.0183
# Epoch 122/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0121 - val_loss: 0.0155
# Epoch 123/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0123 - val_loss: 0.0150
# Epoch 124/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0126 - val_loss: 0.0152
# Epoch 125/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0125 - val_loss: 0.0157
# Epoch 126/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0120 - val_loss: 0.0172
# Epoch 127/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0119 - val_loss: 0.0162
# Epoch 128/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0118 - val_loss: 0.0161
# Epoch 129/3000
# 120/120 [==============================] - 1s 10ms/step - loss: 0.0121 - val_loss: 0.0159
# Epoch 130/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0126 - val_loss: 0.0160
# Epoch 131/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0119 - val_loss: 0.0155
# Epoch 132/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0119 - val_loss: 0.0170
# Epoch 133/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0116 - val_loss: 0.0155
# Epoch 134/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0118 - val_loss: 0.0159
# Epoch 135/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0115 - val_loss: 0.0161
# Epoch 136/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0118 - val_loss: 0.0160
# Epoch 137/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0125 - val_loss: 0.0156
# Epoch 138/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0127 - val_loss: 0.0155
# Epoch 139/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0118 - val_loss: 0.0161
# Epoch 140/3000
# 120/120 [==============================] - 1s 9ms/step - loss: 0.0118 - val_loss: 0.0170

# %%
plt.figure(figsize=(12,5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.ylabel('Mean Squared Error',fontsize=16)
plt.xlabel('Epochs',fontsize=16)
plt.legend(fontsize=14)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)

plt.show()

# %%
model.load_weights('CNN2D.ckpt');

# %%
y_pred = model.predict(X_test)
np.sqrt(mean_squared_error(y_test.reshape(-1, 40*40), y_pred.reshape(-1, 40*40)))
# Out:
# 0.11931360518452323

# %%
k = 78
q = 150

# %%
plt.imshow(y_test[k], cmap='RdYlBu_r', vmax=1, vmin=0)
plt.axis('off');

# %%
plt.imshow(y_pred[k].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)
plt.axis('off');

# %%
plt.imshow(y_train[q], cmap='RdYlBu_r', vmax=1, vmin=0)
plt.axis('off');

# %%
y_train_pred = model.predict(X_train)
plt.imshow(y_train_pred[q].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)
plt.axis('off');

# %%
np.sqrt(mean_squared_error(y_test[k],y_pred[k].reshape(40,-1)))
# Out:
# 0.17040203429900072

# %%
results = [np.sqrt(mean_squared_error(y_test[k],y_pred[k].reshape(40,-1))) for k in range(len(y_test))]

# %%
# best result
results.index(min(results))
# Out:
# 200

# %%
# worst result
results.index(max(results))
# Out:
# 48

# %% [markdown]
# #Hyperparameter Tuning

# %%
def construct_layers(hp,n_inputs):
    layers = []
    out = n_inputs
    i = 1

    while out < 40:
        if out < 36:
            ins = {"input":out,
                "kernel":hp.Int('kernel_' + str(i), min_value=2, max_value=5),
                "stride":1,
                "activation":hp.Choice('CNN_act_' + str(i), values=['tanh','relu', 'selu', 'leaky-relu']),
                "filter":hp.Int('filter_'+str(i), min_value=16, max_value=128, step=16)
                }
        else:
            ins = {"input":out,
                "kernel":41 - out,
                "stride":1,
                "activation":'None',
                "filter":1
                }
        out = (out-1) * ins["stride"] + ins["kernel"]
        i += 1
        ins.update({"output":out})
        layers.append(ins)
    
    return layers

# %%
def generator(hp):
    # Generator model for generating daylight autonomy
    model = Sequential()

    # Setup DNN layers
    DNN_layers = hp.Int('DNN_layers', min_value=0, max_value=4)

    # Setup CNN transpose layers
    hp_initsize = hp.Int('init_size', min_value=5, max_value=9)
    CNN_layers = construct_layers(hp, hp_initsize)

    ### DNN model to analyze the input parameters
    if DNN_layers == 0:
        model.add(Dense(units = CNN_layers[0]["filter"] * hp_initsize * hp_initsize, 
                        activation=hp.Choice('DNN_act_0', values=['tanh', 'relu', 'leaky-relu', 'sigmoid', 'selu']),
                        input_dim=n_feat))
        model.add(BatchNormalization())
    else:
        for i in range(DNN_layers):
            if i == 0:
                model.add(Dense(units = hp.Int('units_' + str(i+1), min_value=16, max_value=256, step=16),
                                activation=hp.Choice('DNN_act_' + str(i+1), values=['relu', 'leaky-relu', 'sigmoid', 'selu']),
                                input_dim=n_feat))
                model.add(BatchNormalization())
            else:
                model.add(Dense(units = hp.Int('units_' + str(i+1), min_value=16, max_value=256, step=16),
                        activation=hp.Choice('DNN_act_' + str(i+1), values=['relu', 'leaky-relu', 'sigmoid', 'selu'])))
                model.add(BatchNormalization())
        model.add(Dense(units = CNN_layers[0]["filter"] * hp_initsize * hp_initsize, 
                        activation=hp.Choice('DNN_act_0', values=['relu', 'leaky-relu', 'sigmoid', 'selu'])))
        model.add(BatchNormalization())

    ### Deconvolution to generate image
    model.add(Reshape((hp_initsize, hp_initsize, CNN_layers[0]["filter"])))

    for layer in CNN_layers[:-1]:
        model.add(Conv2DTranspose(filters=layer["filter"],
                                  kernel_size=layer["kernel"],
                                  strides=(layer["stride"],layer["stride"]),
                                  activation=layer["activation"]))
        model.add(BatchNormalization())
    
    model.add(Conv2DTranspose(filters=CNN_layers[-1]["filter"],
                              kernel_size=CNN_layers[-1]["kernel"],
                              strides=(CNN_layers[-1]["stride"],CNN_layers[-1]["stride"])
                              # , activation='sigmoid'
                              ))

    ### Optimizer
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3])
    hp_epsilon = hp.Choice('epsilon', values=[1e-4, 1e-6, 1e-8])
    hp_beta_1 = hp.Choice('beta_1', values=[0.5, 0.7, 0.9])
    hp_beta_2 = hp.Choice('beta_2', values=[0.99, 0.995, 0.999])
    model.compile(optimizer=optimizers.Adam(learning_rate=hp_learning_rate, 
                                            beta_1=hp_beta_1, beta_2=hp_beta_2,
                                            epsilon=hp_epsilon), 
                  loss="mse"
                  )
    # model.compile(optimizer=optimizers.Adam(learning_rate=1e-3, 
    #                                         beta_1=0.9, beta_2=0.999,
    #                                         epsilon=1e-8), 
    #               loss="mse"
    #               )

    return model

# %%
keras.backend.clear_session()

# %%
hp = kt.HyperParameters()
hp.values["model_type"] = "cnn"

model = generator(hp)
model(X_train)
model.summary()

# %%
tuner = kt.BayesianOptimization(generator, 
                                objective='val_loss',
                                max_trials=200,
                                overwrite=True)

# %%
tuner.search(X_train,
             y_train,
             epochs = 100,
             batch_size = 16,
             validation_data = (X_val, y_val),
             callbacks=[EarlyStopping(monitor='val_loss', patience=30, mode='min')],
             )
# Out:
# Trial 143 Complete [00h 01m 38s]
# val_loss: 0.01484310906380415
#
# Best val_loss So Far: 0.00868965219706297
# Total elapsed time: 04h 40m 10s
#
# Search: Running Trial #144
#
# Hyperparameter    |Value             |Best Value So Far
# DNN_layers        |0                 |0
# init_size         |9                 |5
# kernel_1          |4                 |5
# CNN_act_1         |tanh              |leaky-relu
# filter_1          |48                |48
# kernel_2          |2                 |2
# CNN_act_2         |relu              |tanh
# filter_2          |80                |96
# kernel_3          |2                 |4
# CNN_act_3         |leaky-relu        |relu
# filter_3          |128               |128
# kernel_4          |4                 |3
# CNN_act_4         |leaky-relu        |leaky-relu
# filter_4          |96                |112
# kernel_5          |3                 |4
# CNN_act_5         |selu              |relu
# filter_5          |80                |96
# kernel_6          |5                 |5
# CNN_act_6         |leaky-relu        |leaky-relu
# filter_6          |48                |80
# kernel_7          |5                 |5
# CNN_act_7         |tanh              |leaky-relu
# filter_7          |112               |32
# kernel_8          |5                 |5
# CNN_act_8         |tanh              |leaky-relu
# filter_8          |48                |128
# kernel_9          |5                 |4
# CNN_act_9         |leaky-relu        |leaky-relu
# filter_9          |128               |112
# kernel_10         |4                 |3
# CNN_act_10        |leaky-relu        |relu
# filter_10         |64                |64
# kernel_11         |3                 |5
# CNN_act_11        |relu              |selu
# filter_11         |64                |64
# kernel_12         |3                 |4
# CNN_act_12        |leaky-relu        |selu
# filter_12         |16                |80
# kernel_13         |2                 |4
# CNN_act_13        |relu              |tanh
# filter_13         |64                |64
# kernel_14         |4                 |3
# CNN_act_14        |relu              |tanh
# filter_14         |112               |64
# kernel_15         |2                 |4
# CNN_act_15        |relu              |relu
# filter_15         |80                |80
# kernel_16         |5                 |5
# CNN_act_16        |leaky-relu        |relu
# filter_16         |16                |80
# kernel_17         |5                 |5
# CNN_act_17        |leaky-relu        |leaky-relu
# filter_17         |96                |112
# kernel_18         |3                 |4
# CNN_act_18        |leaky-relu        |leaky-relu
# filter_18         |64                |64
# kernel_19         |3                 |3
# CNN_act_19        |relu              |tanh
# filter_19         |112               |128
# kernel_20         |5                 |5
# CNN_act_20        |relu              |relu
# filter_20         |80                |64
# kernel_21         |2                 |5
# CNN_act_21        |leaky-relu        |tanh
# filter_21         |16                |128
# kernel_22         |2                 |5
# CNN_act_22        |leaky-relu        |selu
# filter_22         |128               |80
# kernel_23         |4                 |3
# CNN_act_23        |tanh              |selu
# filter_23         |48                |48
# kernel_24         |5                 |4
# CNN_act_24        |tanh              |tanh
# filter_24         |48                |112
# kernel_25         |2                 |3
# CNN_act_25        |leaky-relu        |tanh
# filter_25         |16                |48
# kernel_26         |4                 |4
# CNN_act_26        |leaky-relu        |leaky-relu
# filter_26         |128               |16
# kernel_27         |2                 |3
# CNN_act_27        |tanh              |tanh
# filter_27         |16                |64
# kernel_28         |4                 |4
# CNN_act_28        |leaky-relu        |selu
# filter_28         |96                |64
# kernel_29         |5                 |3
# CNN_act_29        |tanh              |tanh
# filter_29         |64                |16
# kernel_30         |3                 |2
# CNN_act_30        |tanh              |selu
# filter_30         |16                |80
# kernel_31         |3                 |4
# CNN_act_31        |leaky-relu        |leaky-relu
# filter_31         |128               |96
# DNN_act_0         |tanh              |tanh
# learning_rate     |0.001             |0.01
# epsilon           |1e-06             |1e-08
# beta_1            |0.9               |0.7
# beta_2            |0.995             |0.99
# units_1           |176               |240
# DNN_act_1         |relu              |leaky-relu
# units_2           |256               |256
# DNN_act_2         |selu              |sigmoid
# units_3           |16                |16
# DNN_act_3         |selu              |relu
# units_4           |16                |96
# DNN_act_4         |leaky-relu        |leaky-relu
#
# Epoch 1/100
#  5/60 [=>............................] - ETA: 0s - loss: 2.9118  WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0061s vs `on_train_batch_end` time: 0.0064s). Check your callbacks.
# 60/60 [==============================] - 3s 23ms/step - loss: 0.3363 - val_loss: 0.3511
# Epoch 2/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0345 - val_loss: 0.1766
# Epoch 3/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0321 - val_loss: 0.0826
# Epoch 4/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0286 - val_loss: 0.0610
# Epoch 5/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0263 - val_loss: 0.0841
# Epoch 6/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0259 - val_loss: 0.0542
# Epoch 7/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0249 - val_loss: 0.0355
# Epoch 8/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0240 - val_loss: 0.0372
# Epoch 9/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0229 - val_loss: 0.0305
# Epoch 10/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0237 - val_loss: 0.0242
# Epoch 11/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0225 - val_loss: 0.0248
# Epoch 12/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0241 - val_loss: 0.0197
# Epoch 13/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0242 - val_loss: 0.0245
# Epoch 14/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0224 - val_loss: 0.0200
# Epoch 15/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0217 - val_loss: 0.0202
# Epoch 16/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0221 - val_loss: 0.0208
# Epoch 17/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0214 - val_loss: 0.0186
# Epoch 18/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0208 - val_loss: 0.0203
# Epoch 19/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0233 - val_loss: 0.0254
# Epoch 20/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0201 - val_loss: 0.0215
# Epoch 21/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0210 - val_loss: 0.0183
# Epoch 22/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0220 - val_loss: 0.0247
# Epoch 23/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0208 - val_loss: 0.0191
# Epoch 24/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0218 - val_loss: 0.0235
# Epoch 25/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0203 - val_loss: 0.0194
# Epoch 26/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0197 - val_loss: 0.0182
# Epoch 27/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0213 - val_loss: 0.0224
# Epoch 28/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0192 - val_loss: 0.0186
# Epoch 29/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0196 - val_loss: 0.0186
# Epoch 30/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0186 - val_loss: 0.0195
# Epoch 31/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0207 - val_loss: 0.0218
# Epoch 32/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0194 - val_loss: 0.0210
# Epoch 33/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0202 - val_loss: 0.0208
# Epoch 34/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0189 - val_loss: 0.0186
# Epoch 35/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0192 - val_loss: 0.0207
# Epoch 36/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0190 - val_loss: 0.0196
# Epoch 37/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0178 - val_loss: 0.0162
# Epoch 38/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0184 - val_loss: 0.0169
# Epoch 39/100
# 60/60 [==============================] - 1s 16ms/step - loss: 0.0184 - val_loss: 0.0185
# Epoch 40/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0184 - val_loss: 0.0178
# Epoch 41/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0190 - val_loss: 0.0179
# Epoch 42/100
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0177 - val_loss: 0.0156
# Epoch 43/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0182 - val_loss: 0.0169
# Epoch 44/100
# 33/60 [===============>..............] - ETA: 0s - loss: 0.0174
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-dc945964c997> in <module>()
#       4              batch_size = 16,
#       5              validation_data = (X_val, y_val),
# ----> 6              callbacks=[EarlyStopping(monitor='val_loss', patience=30, mode='min')],
#       7              )
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     177
#     178             self.on_trial_begin(trial)
# --> 179             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     180             # `results` is None indicates user updated oracle in `run_trial()`.
#     181             if results is None:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     302             callbacks.append(model_checkpoint)
#     303             copied_kwargs["callbacks"] = callbacks
# --> 304             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     305
#     306             # objective left unspecified,
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     232         hp = trial.hyperparameters
#     233         model = self._try_build(hp)
# --> 234         return self.hypermodel.fit(hp, model, *args, **kwargs)
#     235
#     236     def run_trial(self, trial, *args, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     135             If return a float, it should be the `objective` value.
#     136         """
# --> 137         return model.fit(*args, **kwargs)
#     138
#     139
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351       start_time = time.time()
#     352
# --> 353     logs = self._process_logs(logs, is_batch_hook=True)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _process_logs(self, logs, is_batch_hook)
#     270     if is_batch_hook and self._batch_hooks_support_tf_logs:
#     271       return logs
# --> 272     return tf_utils.sync_to_numpy_or_python_type(logs)
#     273
#     274   def append(self, callback):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
best_model = tuner.get_best_models()[0]
best_hp = tuner.get_best_hyperparameters()[0]

# %%
model = tuner.hypermodel.build(best_hp)
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 1200)              15600
#
#  batch_normalization_72 (Bat  (None, 1200)             4800
#  chNormalization)
#
#  reshape_6 (Reshape)         (None, 5, 5, 48)          0
#
#  conv2d_transpose_72 (Conv2D  (None, 9, 9, 48)         57648
#  Transpose)
#
#  batch_normalization_73 (Bat  (None, 9, 9, 48)         192
#  chNormalization)
#
#  conv2d_transpose_73 (Conv2D  (None, 10, 10, 96)       18528
#  Transpose)
#
#  batch_normalization_74 (Bat  (None, 10, 10, 96)       384
#  chNormalization)
#
#  conv2d_transpose_74 (Conv2D  (None, 13, 13, 128)      196736
#  Transpose)
#
#  batch_normalization_75 (Bat  (None, 13, 13, 128)      512
#  chNormalization)
#
#  conv2d_transpose_75 (Conv2D  (None, 15, 15, 112)      129136
#  Transpose)
#
#  batch_normalization_76 (Bat  (None, 15, 15, 112)      448
#  chNormalization)
#
#  conv2d_transpose_76 (Conv2D  (None, 18, 18, 96)       172128
#  Transpose)
#
#  batch_normalization_77 (Bat  (None, 18, 18, 96)       384
#  chNormalization)
#
#  conv2d_transpose_77 (Conv2D  (None, 22, 22, 80)       192080
#  Transpose)
#
#  batch_normalization_78 (Bat  (None, 22, 22, 80)       320
#  chNormalization)
#
#  conv2d_transpose_78 (Conv2D  (None, 26, 26, 32)       64032
#  Transpose)
#
#  batch_normalization_79 (Bat  (None, 26, 26, 32)       128
#  chNormalization)
#
#  conv2d_transpose_79 (Conv2D  (None, 30, 30, 128)      102528
#  Transpose)
#
#  batch_normalization_80 (Bat  (None, 30, 30, 128)      512
#  chNormalization)
#
#  conv2d_transpose_80 (Conv2D  (None, 33, 33, 112)      229488
#  Transpose)
#
#  batch_normalization_81 (Bat  (None, 33, 33, 112)      448
#  chNormalization)
#
#  conv2d_transpose_81 (Conv2D  (None, 35, 35, 64)       64576
#  Transpose)
#
#  batch_normalization_82 (Bat  (None, 35, 35, 64)       256
#  chNormalization)
#
#  conv2d_transpose_82 (Conv2D  (None, 39, 39, 64)       102464
#  Transpose)
#
#  batch_normalization_83 (Bat  (None, 39, 39, 64)       256
#  chNormalization)
#
#  conv2d_transpose_83 (Conv2D  (None, 40, 40, 1)        257
#  Transpose)
#
# =================================================================
# Total params: 1,353,841
# Trainable params: 1,349,521
# Non-trainable params: 4,320
# _________________________________________________________________

# %%
class GenerateImage(keras.callbacks.Callback):
    def __init__(self, xtrain, ytrain, xtest, ytest, monitor_idx):
        self.xtrain = xtrain
        self.ytrain = ytrain
        self.xtest = xtest
        self.ytest = ytest
        self.monitor_idx = [monitor_idx]
    
    def on_epoch_end(self, epoch, logs={}):
        train_sim = self.ytrain[self.monitor_idx]
        train_pred = self.model.predict(self.xtrain[self.monitor_idx])
        test_sim = self.ytest[self.monitor_idx]
        test_pred = self.model.predict(self.xtest[self.monitor_idx])

        fig, ax = plt.subplots(2, 2, figsize=(6, 6))
        display.clear_output(wait=True)

        ax[0, 0].imshow(train_pred[0,:,:,0], cmap='RdYlBu_r', vmin=0, vmax=1)
        ax[0, 1].imshow(train_sim[0,:,:], cmap='RdYlBu_r', vmin=0, vmax=1)
        ax[1, 0].imshow(test_pred[0,:,:,0], cmap='RdYlBu_r', vmin=0, vmax=1)
        ax[1, 1].imshow(test_sim[0,:,:], cmap='RdYlBu_r', vmin=0, vmax=1)

        ax[0,0].set_title('Prediction', size=12)
        ax[0,1].set_title('Simulation', size=12)
        ax[0,0].set_ylabel('Train Sample', size=12)
        ax[1,0].set_ylabel('Test Sample', size=12)

        ax=ax.ravel()
        for a in ax:
            a.set_xticklabels([])
            a.set_yticklabels([])
            a.set_xticks([])
            a.set_yticks([])
        
        plt.savefig(os.path.join(cwd, 'images', 'generated_img', 'image_at_epoch_{:04d}.png'.format(epoch)))
        plt.show()
        plt.close()

# %%
model.fit(X_train,
             y_train,
             epochs = 3000,
             batch_size = 16,
             validation_data = (X_val, y_val),
             callbacks = [EarlyStopping(monitor='val_loss', patience=100, mode='min'),
                          ModelCheckpoint(filepath = 'CNN2D.ckpt', save_weights_only=True, monitor='val_loss', save_best_only=True),
                          GenerateImage(X_train, y_train, X_test, y_test, [256])
                          ]
          )
# Out:
# 60/60 [==============================] - 1s 22ms/step - loss: 0.0066 - val_loss: 0.0091

# %%
model.load_weights('CNN2D.ckpt');

# %%
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# %%
test_results = [np.sqrt(mean_squared_error(y_test[k],y_pred[k].reshape(40,-1))) for k in range(len(y_test))]

# %%
mean = np.mean(test_results)
min(range(len(test_results)), key=lambda i: abs(test_results[i]-mean))
# Out:
# 310

# %%
def compare_plot(sim, pred):
    results = [np.sqrt(mean_squared_error(sim[k],pred[k].reshape(40,-1))) for k in range(len(sim))]

    best_mse = min(results)
    best_idx = results.index(best_mse)

    mid_mse = np.mean(results)
    mid_idx = min(range(len(results)), key=lambda i: abs(results[i]-mid_mse))

    worst_mse = max(results)
    worst_idx = results.index(worst_mse)

    fig, ax = plt.subplots(3,2,sharex=True, sharey=True, figsize=(7,10))

    ax[0,0].imshow(sim[best_idx], cmap='RdYlBu_r', vmax=1, vmin=0)
    ax[0,0].set_title('Simulation', size=15)
    ax[0,0].set_ylabel('Best Case: MSE={:.3f}'.format(best_mse), size=15)

    ax[0,1].imshow(pred[best_idx].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)
    ax[0,1].set_title('Prediction', size=15)

    ax[1,0].imshow(sim[mid_idx], cmap='RdYlBu_r', vmax=1, vmin=0)
    ax[1,0].set_ylabel('Avg Case: MSE={:.3f}'.format(mid_mse), size=15)

    ax[1,1].imshow(pred[mid_idx].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)

    ax[2,0].imshow(sim[worst_idx], cmap='RdYlBu_r', vmax=1, vmin=0)
    ax[2,0].set_ylabel('Worst Case: MSE={:.3f}'.format(worst_mse), size=15)

    ax[2,1].imshow(pred[worst_idx].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)

    ax=ax.ravel()
    for a in ax:
        a.set_xticklabels([])
        a.set_yticklabels([])
        a.set_xticks([])
        a.set_yticks([])

    plt.tight_layout()

# %%
compare_plot(y_test, y_pred)

# %%
compare_plot(y_train, y_train_pred)

# %%
len(y_test)
# Out:
# 200

# %%
# for k in range(0,200,10):
k=50
fig,ax = plt.subplots(1,2,figsize=(7,14))
ax[0].imshow(y_test[k], cmap='RdYlBu_r', vmax=1, vmin=0)
ax[0].set_title('Simulation', size=15)
ax[0].axis(False)
ax[1].imshow(y_pred[k].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)
ax[1].set_title('Prediction', size=15)
ax[1].axis(False);
plt.tight_layout()

# %%
q=89
fig,ax = plt.subplots(1,2,figsize=(7,14))
ax[0].imshow(y_train[q], cmap='RdYlBu_r', vmax=1, vmin=0)
ax[0].set_title('Simulation', size=15)
ax[1].imshow(y_train_pred[q].reshape(40,-1), cmap='RdYlBu_r', vmax=1, vmin=0)
ax[1].set_title('Prediction', size=15)
# Out:
# Text(0.5, 1.0, 'Prediction')

# %% [markdown]
# # Save model

# %%
json = os.path.join(cwd, 'models/UDI_Bayes2.json')
hdf5 = os.path.join(cwd, 'models/UDI_Bayes2.h5')

model_json = model.to_json()
with open(json,'w') as json_file:
    json_file.write(model_json)
model.save_weights(hdf5)

# %% [markdown]
# # Test for random input

# %%
test_case = np.array([4.7,8,6,9.52,2.87,1.25,180,45])

test_pred = model.predict(np.expand_dims(test_case, axis=0))[0].reshape(1,-1)

# %%
plt.imshow(test_pred.reshape(30,-1))
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
